# %%
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
img = cv2.imread('trump_tie_1.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x608 at 0x7FDD5EE91790>

# %%
img = img.reshape((img.shape[0] * img.shape[1],img.shape[2]))

# %%
kmeans = KMeans(n_clusters = 3) 
y_pred = kmeans.fit_predict(img)
centers = kmeans.cluster_centers_

# %%
rgb_centers = []

for c in centers:
  b, g, r = c / 255
  rgb_centers.append([r, g, b])

# %%
plt.imshow([rgb_centers])

# %%
kmeans = KMeans(n_clusters = 5) 
y_pred = kmeans.fit_predict(img)
centers = kmeans.cluster_centers_

# %%
rgb_centers = []

for c in centers:
  b, g, r = c / 255
  rgb_centers.append([r, g, b])

# %%
plt.imshow([rgb_centers])

# %%
kmeans = KMeans(n_clusters = 9) 
y_pred = kmeans.fit_predict(img)
centers = kmeans.cluster_centers_

# %%
rgb_centers = []

for c in centers:
  b, g, r = c / 255
  rgb_centers.append([r, g, b])

# %%
plt.imshow([rgb_centers])
