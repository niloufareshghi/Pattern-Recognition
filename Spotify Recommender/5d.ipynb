# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
    
df = pd.read_csv('/content/a.csv')

# %%
df.corr(method='pearson')
# Out:
#                   Radiojavan_play  Radiojavan_likes  popularity  danceability  \
# Radiojavan_play          1.000000          0.899199    0.393051      0.139250
# Radiojavan_likes         0.899199          1.000000    0.386314      0.104122
# popularity               0.393051          0.386314    1.000000      0.030307
# danceability             0.139250          0.104122    0.030307      1.000000
# energy                   0.152239          0.091210   -0.009942      0.406512
# loudness                 0.134389          0.091314   -0.047609      0.262377
# speechiness              0.093916          0.066407    0.093199      0.169025
# acousticness            -0.040669          0.035668    0.033059     -0.486365
# instrumentalness        -0.028063         -0.028265   -0.037324     -0.124771
# liveness                 0.142855          0.079356    0.020714      0.023998
# valence                  0.198707          0.093013    0.045831      0.432599
# ...

# %%
df = df.drop(columns=['Radiojavan_play', 'energy'])
df.corr(method='pearson')
# Out:
#                   Radiojavan_likes  popularity  danceability  loudness  \
# Radiojavan_likes          1.000000    0.386314      0.104122  0.091314
# popularity                0.386314    1.000000      0.030307 -0.047609
# danceability              0.104122    0.030307      1.000000  0.262377
# loudness                  0.091314   -0.047609      0.262377  1.000000
# speechiness               0.066407    0.093199      0.169025  0.189409
# acousticness              0.035668    0.033059     -0.486365 -0.318227
# instrumentalness         -0.028265   -0.037324     -0.124771 -0.495795
# liveness                  0.079356    0.020714      0.023998  0.138974
# valence                   0.093013    0.045831      0.432599  0.368717
# tempo                    -0.033798   -0.100284     -0.137369  0.056946
# duration_ms              -0.031757    0.055893     -0.129133 -0.305398
#
#                   speechiness  acousticness  instrumentalness  liveness  \
# ...

# %% [markdown]
# Removed two attributes 'play' and 'energy'. 'Radiojavan_play' had a correlation of approx 0.9 with 'Radiojavan_likes' thus it can be removed.
# Also attribute 'energy' had a correlation of 0.7 with loudness.
